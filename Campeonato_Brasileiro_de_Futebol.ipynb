# %% [markdown]
# <a href="https://colab.research.google.com/github/renatologer/A-Linguagem-R/blob/master/Campeonato_Brasileiro_de_Futebol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as Rd

# %%
import requests

# %%
Url='https://pt.wikipedia.org/wiki/Campeonato_Brasileiro_de_Futebol'

# %%
Respostas =requests.get(Url)

# %%
Respostas.text
# Out:
# '\n<!DOCTYPE html>\n<html class="client-nojs" lang="pt" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Campeonato Brasileiro de Futebol – Wikipédia, a enciclopédia livre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janeiro","fevereiro","março","abril","maio","junho","julho","agosto","setembro","outubro","novembro","dezembro"],"wgRequestId":"XpMh1ApAMMMAAhzgpQ8AAAAA","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Campeonato_Brasileiro_de_Futebol","wgTitle":"Campeonato Brasileiro de Futebol","wgCurRevisionId":57999766,"wgRevisionId":57999766,"wgArticleId":20233,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["!CS1 inglês-fontes em língua (en)","!CS1 espanhol-fontes em língua (es)","!Págin
# ...

# %% [markdown]
# Em Html

# %%
Table=Rd.read_html(Respostas.text)

# %% [markdown]
# Para Exibir Respostas.text

# %%
Respostas
# Out:
# <Response [200]>

# %%
Table
# Out:
# [                     Campeonato Brasileiro de Futebol
#                                            Brasileirão                                      Brasileirão.1
#  0                     Logotipo oficial da competição.                    Logotipo oficial da competição.
#  1                                        Dados gerais                                       Dados gerais
#  2                                         Organização                                                CBF
#  3                                             Edições  63 (10 em mata-mata, 36 em sistema misto e 17 ...
#  4                                        Outros nomes                                        Brasileirão
#  5                                    Local de disputa                                             Brasil
#  6                                   Número de equipes                                                 20
# ...

# %%
Df=Table[14]

# %%
Df.head(15)
# Out:
#                    Clube  ...                                       Quarto lugar
# 0              Palmeiras  ...  7 (1964, 1965, 1968,[nota 3] 1979, 2004, 2005 ...
# 1                 Santos  ...                                           1 (2006)
# 2            Corinthians  ...                  5 (1971, 1972, 1982, 1984 e 2014)
# 3              São Paulo  ...                        4 (1993, 1999, 2012 e 2015)
# 4               Flamengo  ...                                           1 (2011)
# 5               Cruzeiro  ...                      3 (1967[nota 5], 1970 e 2009)
# 6          Vasco da Gama  ...                                    2 (1959 e 1978)
# 7             Fluminense  ...            6 (1966, 1976, 1991, 1995, 2002 e 2007)
# 8          Internacional  ...                              3 (1973, 1974 e 1987)
# 9                 Grêmio  ...  7 (1967[nota 3], 1988, 2000, 2010, 2017, 2018 ...
# 10              Botafogo  ...                  5 (1963, 1969, 1981, 1989 e 2013)
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Clube           32 non-null     object
#  1   Títulos         32 non-null     object
#  2   Vices           32 non-null     object
#  3   Terceiro lugar  32 non-null     object
#  4   Quarto lugar    32 non-null     object
# dtypes: object(5)
# memory usage: 1.4+ KB

# %%
Df['Vices']=Df['Vices'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-83d434d3a163> in <module>()
# ----> 1 Df['Vices']=Df['Vices'].astype(float)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
Df['Vices']=Df['Vices'].str.replace('(','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-ab350c44ab5d> in <module>()
# ----> 1 Df['Vices']=Df['Vices'].str.replace('(','').astype(int)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-2c554e77e702> in <module>()
# ----> 1 Df['Vices']=Df['Vices'].s.replace(')','').astype(int)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 's'

# %%
 Df['Vices']=Df['Vices'].str.replace('nota','')

# %%
string(float("Títulos"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-a28d990bb554> in <module>()
# ----> 1 string(float("Títulos"))
#
# NameError: name 'string' is not defined

# %%
print(Os)
# Out:
# ['Vices']

# %%
 Df['Títulos']=Df['Títulos'].str.replace('nota','')

# %%
Df['Títulos']=Df['Títulos'].str.replace('(','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-f1f1ca23c56e> in <module>()
# ----> 1 Df['Títulos']=Df['Títulos'].str.replace('(','').astype(int)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
Filtra= '1234567890'

# %%
def Filtra_String (str,filter):
     New_Str=''
     for char in str:
         if char in filtra: 
             New_Str+=char
             return New_Str

# %%
 Df['Vices']=Df['Vices'].str.replace('nota','')

# %%
Df['Títulos']=Df['Títulos'].str.replace('(','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-f1f1ca23c56e> in <module>()
# ----> 1 Df['Títulos']=Df['Títulos'].str.replace('(','').astype(int)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
Lol=Df

# %%
Nova=Filtra_String(Df,Filtra)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-5daa040f2d4e> in <module>()
# ----> 1 Nova=Filtra_String(Df,Filtra)
#
# <ipython-input-80-91e0323e7ab0> in Filtra_String(str, filter)
#       2      New_Str=''
#       3      for char in str:
# ----> 4          if char in filtra:
#       5              New_Str+=char
#       6              return New_Str
#
# NameError: name 'filtra' is not defined
